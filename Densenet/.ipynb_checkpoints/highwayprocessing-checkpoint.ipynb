# %%
from __future__ import print_function
from __future__ import absolute_import
from __future__ import division
from keras.regularizers import l2
from keras.engine.topology import get_source_inputs

import keras.backend as KB

import pickle
import numpy as np 
import os
import skimage.io as io
import skimage.transform as trans
import numpy as np
import random

import keras as K
from keras.models import *
from keras.layers import *
from keras.optimizers import *
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras import backend as keras
import matplotlib

import matplotlib.pyplot as plt
plt.switch_backend('agg')

import cv2
from keras.utils.vis_utils import plot_model
from IPython.display import Image, display

from PIL import Image
# Out:
# /home/rajat/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
class HighwayDataset:
    def imread(self , name):
      
        return cv2.cvtColor(cv2.imread(name) , cv2.COLOR_RGB2BGR)

    def image2class(self , image):
        img = np.zeros((image.shape[0],image.shape[1]))
        for i,t in enumerate(self.color_list):
            img[np.all(image == t[0] , axis = -1)] = i
        return img

    def class2onehot(self , classm):
        return (np.arange(self.nb_classes) == classm[...,None]).astype(np.int8)

    def class2image(self , classm):
        img = np.zeros((classm.shape[0],classm.shape[1],3))
        for i,t in enumerate(self.color_list):
            img[classm == i] = np.array(t[0])
        return img.astype(np.uint8)

    def image_file(self , name):
        return self.images_dir+'/'+name
    
    def label_file_segmentation(self , name):
        return self.labels_dir+'/'+(name.split('.')[0]).split('_')[0]+self.label_suffix + (name.split('.')[0]).split('_')[3]+'.png'
  

    def label_file(self , name):
#         print(self.labels_dir+'/'+(name.split('.')[0]).split('_')[0]+self.label_suffix + (name.split('.')[0]).split('_')[2]+'.png')
        return self.labels_dir+'/'+(name.split('.')[0]).split('_')[0]+self.label_suffix + (name.split('.')[0]).split('_')[2]+'.png'
  
    def __init__(self ,images_dir , labels_dir , classes = None):
        self.color_list =   [           
                                            ([0,0,0]          , 'Void'),
                                            ([0, 0, 128]      , 'Car'),
                                            ([255, 0 , 0]     , 'Fence'),
                                            ([128, 128, 128]  , 'Road'),
                                            ([0,255,255]      , 'Sky'),
                                            ([255,0,128]      , 'Traffic Sign'),
                                            ([0, 128, 0]      , 'Vegetation'),
                                            ([255,255,0]      , 'Lane'),
                                            ([128,0,128]      , 'Construction'),
                                            ([0,128,128]      , 'Truck'),
                                            ([255,255,255]    , 'Unknown')
                                        ]

        if classes is not None:
            assert(isinstance(classes,list) ) ,"log:give a list of classes, check dataset or code"
            color_list = [self.color_list[0]]
            for t in self.color_list[1:]:
                if t[1] in classes:
                    color_list.append(t)
            self.color_list = color_list

        self.nb_classes  = len(self.color_list)   
        print("log: after filtering there are ",self.nb_classes," classes for training")                          


        image_name_list = os.listdir(images_dir)
        list.sort(image_name_list)
        labels_name_list = os.listdir(labels_dir)
        self.split_char = '_'
        self.label_suffix= '_ColorLabel_'
        
        image_sequence_dict = {}

        for name in image_name_list:          
            n = (name.split(self.split_char))[0]
            image_sequence_dict.setdefault(n , [])
            image_sequence_dict[n].append(name)

        self.images_dir = 'HighwayDriving/images'
        self.labels_dir = 'HighwayDriving/labels'
        self.image_name_list = image_name_list
        self.labels_name_list = labels_name_list
        self.image_sequence_dict = image_sequence_dict
        
#         print(image_sequence_dict)     
    
    
    def frame2label_train_datagen(self ,size = None  ,  batch_size = 16 , validation = True , normalise = True):
        
        train_images = self.image_name_list
        
        if validation == True:
            train_images = self.image_name_list[:int(len(self.image_name_list)*0.9)]

        random.shuffle(train_images)
        itr = len(train_images) // batch_size 
        for i in range(itr+1):
            
            IMAGES = []
            LABELS = []
            beg = i*batch_size
            end = (i*batch_size + batch_size) if (i*batch_size + batch_size) < len(train_images) else -1
            for img_file in train_images[beg:end]:
                image = self.imread(self.image_file(img_file))
                label = self.image2class(self.imread(self.label_file_segmentation(img_file)))                 
                
                if size != None:
                    assert( len(size) == 2) , "log: give (y , x) format size"
                    image = cv2.resize(image , size , interpolation = cv2.INTER_NEAREST)
                    label = cv2.resize(label , size , interpolation = cv2.INTER_NEAREST) 
                    
                label = self.class2onehot(label)
                IMAGES.append(image)
                LABELS.append(label)
            IMAGES = np.array(IMAGES)
            LABELS = np.array(LABELS)
            if normalise:
                IMAGES = IMAGES/255

            yield np.array(IMAGES),np.array(LABELS)
        
    def jaccard_index(y_pred , y):
        intersection = np.logical_and(y, y_pred)
        union = np.logical_or(y, y_pred)
        iou_score = np.sum(intersection) / np.sum(union)
        return iou_score


    def get_class_weights(self , c=1.02):
        _ , labels = next(self.frame2label_train_datagen(size = (256 , 256)  ,  batch_size = len(self.image_name_list), validation = False , normalise = False))
        labels = np.argmax(labels , axis = -1)
        print(labels.shape)
        all_labels = labels.flatten()
        each_class = np.bincount(all_labels, minlength=self.nb_classes)
        prospensity_score = each_class / len(all_labels)
        class_weights = 1 / (np.log(c + prospensity_score))
        return class_weights
        
    def frame2futurelabel_train_datagen(self , size=None , batch_size = 16 , time_step = 1 , normalise = True):
        assert(batch_size > time_step) ,'log: batch size must be greater than time step'   

        for sequence in self.image_sequence_dict.keys():            
            train_images = self.image_sequence_dict[sequence]
            itr = len(train_images) // batch_size
            for i in range(itr+1):
                IMAGES = []
                IMAGES_FUTURE = []
                LABELS_FUTURE = []
                beg = i*batch_size
                end = (i*batch_size + batch_size) if (i*batch_size + batch_size) < len(train_images) else -1
                train_batch = self.image_sequence_dict[sequence][beg:end ]
                
                for i in range(len(train_batch)-time_step):
#                     print(train_batch[i])
                    frame1 = self.image_file(sequence+'_RGB_Image_'+(train_batch[i]).split('_')[3])
                    frame2 = self.image_file(sequence+'_RGB_Image_'+(train_batch[i+time_step]).split('_')[3])
                    label2 = self.label_file((sequence)+'_ColorLabel_'+(train_batch[i+time_step]).split('_')[3])
                    frame1_image = self.imread(frame1)
                    frame2_image = self.imread(frame2)
                    label2_classim = self.image2class(self.imread(label2))
                    if size != None:
                        assert( len(size) == 2) , "log: give (y , x) format size"
                        frame1_image = cv2.resize(frame1_image , size , interpolation = cv2.INTER_NEAREST)
                        frame2_image = cv2.resize(frame2_image , size , interpolation = cv2.INTER_NEAREST)
                        label2_classim = cv2.resize(label2_classim , size , interpolation = cv2.INTER_NEAREST)
                    label2_onehote = self.class2onehot(label2_classim)
                    IMAGES.append(frame1_image)
                    IMAGES_FUTURE.append(frame2_image)
                    LABELS_FUTURE.append(label2_onehote)

                IMAGES = np.array(IMAGES)
                IMAGES_FUTURE = np.array(IMAGES_FUTURE)
                LABELS_FUTURE = np.array(LABELS_FUTURE)

                if normalise:
                    IMAGES_FUTURE =IMAGES_FUTURE/255
                    IMAGES = IMAGES/255


                yield IMAGES , IMAGES_FUTURE , LABELS_FUTURE

# %%
proc=HighwayDataset('HighwayDriving/images','HighwayDriving/labels', classes= None)
# x,l = proc.frame2label_train_datagen(size = (256,256)  ,  batch_size = 16 , validation = True , normalise = True)
# x,f,fl = proc.frame2futurelabel_train_datagen(size=(256,256) , batch_size = 16 , time_step = 1 , normalise = True)
# Out:
# log: after filtering there are  11  classes for training

# %%
nb_classes = proc.nb_classes
# class_weights = proc.get_class_weights()
# print(class_weights)

# %%
def jaccard_distance(y_true, y_pred, smooth=100):
   
    intersection = K.sum(K.abs(y_true * y_pred), axis=-1)
    sum_ = K.sum(K.abs(y_true) + K.abs(y_pred), axis=-1)
    jac = (intersection + smooth) / (sum_ - intersection + smooth)
    return (1 - jac) * smooth

# %%
def conv_block(x,nb_filter,dropout_rate):
    x=BatchNormalization()(x)
    x=Activation('relu')(x)
    x=Conv2D(nb_filter,(3,3),kernel_initializer='he_uniform',padding='same')(x)
    x=Dropout(dropout_rate)(x)
    return x

def transition_down(x,nb_filter,dropout_rate):
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Conv2D(nb_filter, (1, 1),kernel_initializer="he_uniform",padding="same",activation=None)(x)

    x = Dropout(dropout_rate)(x)
    x = MaxPooling2D((2, 2), strides=(2, 2))(x)

    return x

def transition_up(x,nb_filter):
    
    x = Conv2DTranspose(nb_filter,kernel_size=(3, 3), strides=(2,2),kernel_initializer="he_uniform",padding="same",activation=None)(x)
    return x

def denseblock(x,nb_layers,growth_rate,dropout_rate):
    lists=[x]
    for i in range(nb_layers):
        x=conv_block(x,growth_rate,dropout_rate)
        lists.append(x)
        if i ==  nb_layers - 1:
            x=Concatenate(axis=-1)(lists[1:])
        else:
            x=Concatenate(axis=-1)(lists)
    
    return x,(nb_layers * growth_rate)
    
  
  
def densenet(nb_classes, img_dim,growth_rate , nb_layers = [4,5,7,10,12] ,dropout_rate = 0.2 ,input_size = 48):
    concat_axis=-1
    inputs=Input(shape=img_dim)
    x=Conv2D(filters=input_size,kernel_size=(3,3),kernel_initializer="he_uniform",padding="same")(inputs)
    
    dense_outputs = []
    for nb_layer in nb_layers:
        dense,f = denseblock(x,nb_layers=nb_layer,growth_rate=growth_rate,dropout_rate=dropout_rate)
        x = Concatenate(axis = -1)([x , dense])
        dense_outputs.append(x)
        x = transition_down(x,f+input_size,dropout_rate=dropout_rate)
        input_size = f+input_size
    
    dense,f = denseblock(x,nb_layers=15,growth_rate=growth_rate,dropout_rate=dropout_rate)
    x = Concatenate(axis = -1)([x , dense])
    input_size = f
    
    
    dense_outputs=(dense_outputs)[::-1]
    nb_layers=(nb_layers)[::-1]
    
    for i in range(0,5):
        
        x=transition_up(x,input_size)
        x=Concatenate(axis=-1)([x,dense_outputs[i]])  
        dense,f = denseblock(x,nb_layers=nb_layers[i],growth_rate=growth_rate,dropout_rate=dropout_rate)
        x=Concatenate(axis=-1)([x,dense])
        input_size=f
    
    x=Conv2D(filters=nb_classes,kernel_size=(1,1),kernel_initializer="he_uniform",padding="same",activation= 'softmax')(x)
    
    model=Model(inputs=[inputs],outputs=[x])
#     model.summary()
    model.compile(optimizer = RMSprop(lr = 1e-3), loss = 'categorical_crossentropy', metrics = [jaccard_distance])
    return model

# %%
epochs=1
model = densenet(nb_classes=nb_classes,img_dim=(256,256,3),growth_rate=16)
image = None
image_future = None
label_future = None
# model.load_weights("model/densenet_model_weight_ep100.hdf5")

for e in range(1,epochs+1):
    for x , x_f, l_f in proc.frame2futurelabel_train_datagen(size=(256,256) , batch_size = 16 , time_step = 1 , normalise = True):
        image , label_future, image_future = x[:1] , l_f[:1], x_f[:1] 
        history = model.fit(x, l_f, batch_size=4, epochs=1,verbose=1) 
        print("Loss :",history.history['loss'] , " Jaccard Distance :", history.history['jaccard_distance'])
    
    model.save_weights("models/newDensenetEpoch{}.h5".format(e))
    print("model saved")        
    break
#     pred = model.predict(image)
#     pred_classm = np.argmax(pred[0] , axis = -1)
#     print(pred_classm)
#     pred_label = proc.class2image(pred_classm)    
    
#     label_classm = np.argmax(label[0] , axis = -1)
#     label_label = proc.class2image(label_classm)
    
    
#     image = (image[0] * 255).astype(np.uint8)
#     figure = plt.figure(figsize=(15, 15))
#     plt.subplot(1, 3, 1)
#     plt.title("image")
#     plt.imshow(image)
#     plt.subplot(1,3,2)
#     plt.title("pred_label")
#     plt.imshow(pred_label)
#     plt.subplot(1,3,3)
#     plt.title("actual label")
#     plt.imshow(label_label)
#     plt.show()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_5 (InputLayer)            (None, 256, 256, 3)  0
# __________________________________________________________________________________________________
# conv2d_393 (Conv2D)             (None, 256, 256, 48) 1344        input_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_385 (BatchN (None, 256, 256, 48) 192         conv2d_393[0][0]
# __________________________________________________________________________________________________
# activation_385 (Activation)     (None, 256, 256, 48) 0           batch_normalization_385[0][0]
# __________________________________________________________________________________________________
# conv2d_394 (Conv2D)             (None, 256, 256, 16) 6928        activation_385[0][0]
# __________________________________________________________________________________________________
# dropout_385 (Dropout)           (None, 256, 256, 16) 0           conv2d_394[0][0]
# __________________________________________________________________________________________________
# concatenate_429 (Concatenate)   (None, 256, 256, 64) 0           conv2d_393[0][0]
#                                                                  dropout_385[0][0]
# __________________________________________________________________________________________________
# batch_normalization_386 (BatchN (None, 256, 256, 64) 256         concatenate_429[0][0]
# __________________________________________________________________________________________________
# activation_386 (Activation)     (None, 256, 256, 64) 0           batch_normalization_386[0][0]
# __________________________________________________________________________________________________
# conv2d_395 (Conv2D)             (None, 256, 256, 16) 9232        activation_386[0][0]
# __________________________________________________________________________________________________
# dropout_386 (Dropout)           (None, 256, 256, 16) 0           conv2d_395[0][0]
# __________________________________________________________________________________________________
# concatenate_430 (Concatenate)   (None, 256, 256, 80) 0           conv2d_393[0][0]
#                                                                  dropout_385[0][0]
#                                                                  dropout_386[0][0]
# __________________________________________________________________________________________________
# batch_normalization_387 (BatchN (None, 256, 256, 80) 320         concatenate_430[0][0]
# __________________________________________________________________________________________________
# activation_387 (Activation)     (None, 256, 256, 80) 0           batch_normalization_387[0][0]
# __________________________________________________________________________________________________
# conv2d_396 (Conv2D)             (None, 256, 256, 16) 11536       activation_387[0][0]
# __________________________________________________________________________________________________
# dropout_387 (Dropout)           (None, 256, 256, 16) 0           conv2d_396[0][0]
# __________________________________________________________________________________________________
# concatenate_431 (Concatenate)   (None, 256, 256, 96) 0           conv2d_393[0][0]
#                                                                  dropout_385[0][0]
#                                                                  dropout_386[0][0]
#                                                                  dropout_387[0][0]
# __________________________________________________________________________________________________
# batch_normalization_388 (BatchN (None, 256, 256, 96) 384         concatenate_431[0][0]
# __________________________________________________________________________________________________
# activation_388 (Activation)     (None, 256, 256, 96) 0           batch_normalization_388[0][0]
# __________________________________________________________________________________________________
# conv2d_397 (Conv2D)             (None, 256, 256, 16) 13840       activation_388[0][0]
# __________________________________________________________________________________________________
# dropout_388 (Dropout)           (None, 256, 256, 16) 0           conv2d_397[0][0]
# __________________________________________________________________________________________________
# concatenate_432 (Concatenate)   (None, 256, 256, 64) 0           dropout_385[0][0]
#                                                                  dropout_386[0][0]
#                                                                  dropout_387[0][0]
#                                                                  dropout_388[0][0]
# __________________________________________________________________________________________________
# concatenate_433 (Concatenate)   (None, 256, 256, 112 0           conv2d_393[0][0]
#                                                                  concatenate_432[0][0]
# __________________________________________________________________________________________________
# batch_normalization_389 (BatchN (None, 256, 256, 112 448         concatenate_433[0][0]
# __________________________________________________________________________________________________
# activation_389 (Activation)     (None, 256, 256, 112 0           batch_normalization_389[0][0]
# __________________________________________________________________________________________________
# conv2d_398 (Conv2D)             (None, 256, 256, 112 12656       activation_389[0][0]
# __________________________________________________________________________________________________
# dropout_389 (Dropout)           (None, 256, 256, 112 0           conv2d_398[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_21 (MaxPooling2D) (None, 128, 128, 112 0           dropout_389[0][0]
# __________________________________________________________________________________________________
# batch_normalization_390 (BatchN (None, 128, 128, 112 448         max_pooling2d_21[0][0]
# __________________________________________________________________________________________________
# activation_390 (Activation)     (None, 128, 128, 112 0           batch_normalization_390[0][0]
# __________________________________________________________________________________________________
# conv2d_399 (Conv2D)             (None, 128, 128, 16) 16144       activation_390[0][0]
# __________________________________________________________________________________________________
# dropout_390 (Dropout)           (None, 128, 128, 16) 0           conv2d_399[0][0]
# __________________________________________________________________________________________________
# concatenate_434 (Concatenate)   (None, 128, 128, 128 0           max_pooling2d_21[0][0]
#                                                                  dropout_390[0][0]
# __________________________________________________________________________________________________
# batch_normalization_391 (BatchN (None, 128, 128, 128 512         concatenate_434[0][0]
# __________________________________________________________________________________________________
# activation_391 (Activation)     (None, 128, 128, 128 0           batch_normalization_391[0][0]
# __________________________________________________________________________________________________
# conv2d_400 (Conv2D)             (None, 128, 128, 16) 18448       activation_391[0][0]
# __________________________________________________________________________________________________
# dropout_391 (Dropout)           (None, 128, 128, 16) 0           conv2d_400[0][0]
# __________________________________________________________________________________________________
# concatenate_435 (Concatenate)   (None, 128, 128, 144 0           max_pooling2d_21[0][0]
#                                                                  dropout_390[0][0]
#                                                                  dropout_391[0][0]
# __________________________________________________________________________________________________
# batch_normalization_392 (BatchN (None, 128, 128, 144 576         concatenate_435[0][0]
# __________________________________________________________________________________________________
# activation_392 (Activation)     (None, 128, 128, 144 0           batch_normalization_392[0][0]
# __________________________________________________________________________________________________
# conv2d_401 (Conv2D)             (None, 128, 128, 16) 20752       activation_392[0][0]
# __________________________________________________________________________________________________
# dropout_392 (Dropout)           (None, 128, 128, 16) 0           conv2d_401[0][0]
# __________________________________________________________________________________________________
# concatenate_436 (Concatenate)   (None, 128, 128, 160 0           max_pooling2d_21[0][0]
#                                                                  dropout_390[0][0]
#                                                                  dropout_391[0][0]
#                                                                  dropout_392[0][0]
# __________________________________________________________________________________________________
# batch_normalization_393 (BatchN (None, 128, 128, 160 640         concatenate_436[0][0]
# __________________________________________________________________________________________________
# activation_393 (Activation)     (None, 128, 128, 160 0           batch_normalization_393[0][0]
# __________________________________________________________________________________________________
# conv2d_402 (Conv2D)             (None, 128, 128, 16) 23056       activation_393[0][0]
# __________________________________________________________________________________________________
# dropout_393 (Dropout)           (None, 128, 128, 16) 0           conv2d_402[0][0]
# __________________________________________________________________________________________________
# concatenate_437 (Concatenate)   (None, 128, 128, 176 0           max_pooling2d_21[0][0]
#                                                                  dropout_390[0][0]
#                                                                  dropout_391[0][0]
#                                                                  dropout_392[0][0]
#                                                                  dropout_393[0][0]
# __________________________________________________________________________________________________
# batch_normalization_394 (BatchN (None, 128, 128, 176 704         concatenate_437[0][0]
# __________________________________________________________________________________________________
# activation_394 (Activation)     (None, 128, 128, 176 0           batch_normalization_394[0][0]
# __________________________________________________________________________________________________
# conv2d_403 (Conv2D)             (None, 128, 128, 16) 25360       activation_394[0][0]
# __________________________________________________________________________________________________
# dropout_394 (Dropout)           (None, 128, 128, 16) 0           conv2d_403[0][0]
# __________________________________________________________________________________________________
# concatenate_438 (Concatenate)   (None, 128, 128, 80) 0           dropout_390[0][0]
#                                                                  dropout_391[0][0]
#                                                                  dropout_392[0][0]
#                                                                  dropout_393[0][0]
#                                                                  dropout_394[0][0]
# __________________________________________________________________________________________________
# concatenate_439 (Concatenate)   (None, 128, 128, 192 0           max_pooling2d_21[0][0]
#                                                                  concatenate_438[0][0]
# __________________________________________________________________________________________________
# batch_normalization_395 (BatchN (None, 128, 128, 192 768         concatenate_439[0][0]
# __________________________________________________________________________________________________
# activation_395 (Activation)     (None, 128, 128, 192 0           batch_normalization_395[0][0]
# __________________________________________________________________________________________________
# conv2d_404 (Conv2D)             (None, 128, 128, 192 37056       activation_395[0][0]
# __________________________________________________________________________________________________
# dropout_395 (Dropout)           (None, 128, 128, 192 0           conv2d_404[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_22 (MaxPooling2D) (None, 64, 64, 192)  0           dropout_395[0][0]
# __________________________________________________________________________________________________
# batch_normalization_396 (BatchN (None, 64, 64, 192)  768         max_pooling2d_22[0][0]
# __________________________________________________________________________________________________
# activation_396 (Activation)     (None, 64, 64, 192)  0           batch_normalization_396[0][0]
# __________________________________________________________________________________________________
# conv2d_405 (Conv2D)             (None, 64, 64, 16)   27664       activation_396[0][0]
# __________________________________________________________________________________________________
# dropout_396 (Dropout)           (None, 64, 64, 16)   0           conv2d_405[0][0]
# __________________________________________________________________________________________________
# concatenate_440 (Concatenate)   (None, 64, 64, 208)  0           max_pooling2d_22[0][0]
#                                                                  dropout_396[0][0]
# __________________________________________________________________________________________________
# batch_normalization_397 (BatchN (None, 64, 64, 208)  832         concatenate_440[0][0]
# __________________________________________________________________________________________________
# activation_397 (Activation)     (None, 64, 64, 208)  0           batch_normalization_397[0][0]
# __________________________________________________________________________________________________
# conv2d_406 (Conv2D)             (None, 64, 64, 16)   29968       activation_397[0][0]
# __________________________________________________________________________________________________
# dropout_397 (Dropout)           (None, 64, 64, 16)   0           conv2d_406[0][0]
# __________________________________________________________________________________________________
# concatenate_441 (Concatenate)   (None, 64, 64, 224)  0           max_pooling2d_22[0][0]
#                                                                  dropout_396[0][0]
#                                                                  dropout_397[0][0]
# __________________________________________________________________________________________________
# batch_normalization_398 (BatchN (None, 64, 64, 224)  896         concatenate_441[0][0]
# __________________________________________________________________________________________________
# activation_398 (Activation)     (None, 64, 64, 224)  0           batch_normalization_398[0][0]
# __________________________________________________________________________________________________
# conv2d_407 (Conv2D)             (None, 64, 64, 16)   32272       activation_398[0][0]
# __________________________________________________________________________________________________
# dropout_398 (Dropout)           (None, 64, 64, 16)   0           conv2d_407[0][0]
# __________________________________________________________________________________________________
# concatenate_442 (Concatenate)   (None, 64, 64, 240)  0           max_pooling2d_22[0][0]
#                                                                  dropout_396[0][0]
#                                                                  dropout_397[0][0]
#                                                                  dropout_398[0][0]
# __________________________________________________________________________________________________
# batch_normalization_399 (BatchN (None, 64, 64, 240)  960         concatenate_442[0][0]
# __________________________________________________________________________________________________
# activation_399 (Activation)     (None, 64, 64, 240)  0           batch_normalization_399[0][0]
# __________________________________________________________________________________________________
# conv2d_408 (Conv2D)             (None, 64, 64, 16)   34576       activation_399[0][0]
# __________________________________________________________________________________________________
# dropout_399 (Dropout)           (None, 64, 64, 16)   0           conv2d_408[0][0]
# __________________________________________________________________________________________________
# concatenate_443 (Concatenate)   (None, 64, 64, 256)  0           max_pooling2d_22[0][0]
#                                                                  dropout_396[0][0]
#                                                                  dropout_397[0][0]
#                                                                  dropout_398[0][0]
#                                                                  dropout_399[0][0]
# __________________________________________________________________________________________________
# batch_normalization_400 (BatchN (None, 64, 64, 256)  1024        concatenate_443[0][0]
# __________________________________________________________________________________________________
# activation_400 (Activation)     (None, 64, 64, 256)  0           batch_normalization_400[0][0]
# __________________________________________________________________________________________________
# conv2d_409 (Conv2D)             (None, 64, 64, 16)   36880       activation_400[0][0]
# __________________________________________________________________________________________________
# dropout_400 (Dropout)           (None, 64, 64, 16)   0           conv2d_409[0][0]
# __________________________________________________________________________________________________
# concatenate_444 (Concatenate)   (None, 64, 64, 272)  0           max_pooling2d_22[0][0]
#                                                                  dropout_396[0][0]
#                                                                  dropout_397[0][0]
#                                                                  dropout_398[0][0]
#                                                                  dropout_399[0][0]
#                                                                  dropout_400[0][0]
# __________________________________________________________________________________________________
# batch_normalization_401 (BatchN (None, 64, 64, 272)  1088        concatenate_444[0][0]
# __________________________________________________________________________________________________
# activation_401 (Activation)     (None, 64, 64, 272)  0           batch_normalization_401[0][0]
# __________________________________________________________________________________________________
# conv2d_410 (Conv2D)             (None, 64, 64, 16)   39184       activation_401[0][0]
# __________________________________________________________________________________________________
# dropout_401 (Dropout)           (None, 64, 64, 16)   0           conv2d_410[0][0]
# __________________________________________________________________________________________________
# concatenate_445 (Concatenate)   (None, 64, 64, 288)  0           max_pooling2d_22[0][0]
#                                                                  dropout_396[0][0]
#                                                                  dropout_397[0][0]
#                                                                  dropout_398[0][0]
#                                                                  dropout_399[0][0]
#                                                                  dropout_400[0][0]
#                                                                  dropout_401[0][0]
# __________________________________________________________________________________________________
# batch_normalization_402 (BatchN (None, 64, 64, 288)  1152        concatenate_445[0][0]
# __________________________________________________________________________________________________
# activation_402 (Activation)     (None, 64, 64, 288)  0           batch_normalization_402[0][0]
# __________________________________________________________________________________________________
# conv2d_411 (Conv2D)             (None, 64, 64, 16)   41488       activation_402[0][0]
# __________________________________________________________________________________________________
# dropout_402 (Dropout)           (None, 64, 64, 16)   0           conv2d_411[0][0]
# __________________________________________________________________________________________________
# concatenate_446 (Concatenate)   (None, 64, 64, 112)  0           dropout_396[0][0]
#                                                                  dropout_397[0][0]
#                                                                  dropout_398[0][0]
#                                                                  dropout_399[0][0]
#                                                                  dropout_400[0][0]
#                                                                  dropout_401[0][0]
#                                                                  dropout_402[0][0]
# __________________________________________________________________________________________________
# concatenate_447 (Concatenate)   (None, 64, 64, 304)  0           max_pooling2d_22[0][0]
#                                                                  concatenate_446[0][0]
# __________________________________________________________________________________________________
# batch_normalization_403 (BatchN (None, 64, 64, 304)  1216        concatenate_447[0][0]
# __________________________________________________________________________________________________
# activation_403 (Activation)     (None, 64, 64, 304)  0           batch_normalization_403[0][0]
# __________________________________________________________________________________________________
# conv2d_412 (Conv2D)             (None, 64, 64, 304)  92720       activation_403[0][0]
# __________________________________________________________________________________________________
# dropout_403 (Dropout)           (None, 64, 64, 304)  0           conv2d_412[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_23 (MaxPooling2D) (None, 32, 32, 304)  0           dropout_403[0][0]
# __________________________________________________________________________________________________
# batch_normalization_404 (BatchN (None, 32, 32, 304)  1216        max_pooling2d_23[0][0]
# __________________________________________________________________________________________________
# activation_404 (Activation)     (None, 32, 32, 304)  0           batch_normalization_404[0][0]
# __________________________________________________________________________________________________
# conv2d_413 (Conv2D)             (None, 32, 32, 16)   43792       activation_404[0][0]
# __________________________________________________________________________________________________
# dropout_404 (Dropout)           (None, 32, 32, 16)   0           conv2d_413[0][0]
# __________________________________________________________________________________________________
# concatenate_448 (Concatenate)   (None, 32, 32, 320)  0           max_pooling2d_23[0][0]
#                                                                  dropout_404[0][0]
# __________________________________________________________________________________________________
# batch_normalization_405 (BatchN (None, 32, 32, 320)  1280        concatenate_448[0][0]
# __________________________________________________________________________________________________
# activation_405 (Activation)     (None, 32, 32, 320)  0           batch_normalization_405[0][0]
# __________________________________________________________________________________________________
# conv2d_414 (Conv2D)             (None, 32, 32, 16)   46096       activation_405[0][0]
# __________________________________________________________________________________________________
# dropout_405 (Dropout)           (None, 32, 32, 16)   0           conv2d_414[0][0]
# __________________________________________________________________________________________________
# concatenate_449 (Concatenate)   (None, 32, 32, 336)  0           max_pooling2d_23[0][0]
#                                                                  dropout_404[0][0]
#                                                                  dropout_405[0][0]
# __________________________________________________________________________________________________
# batch_normalization_406 (BatchN (None, 32, 32, 336)  1344        concatenate_449[0][0]
# __________________________________________________________________________________________________
# activation_406 (Activation)     (None, 32, 32, 336)  0           batch_normalization_406[0][0]
# __________________________________________________________________________________________________
# conv2d_415 (Conv2D)             (None, 32, 32, 16)   48400       activation_406[0][0]
# __________________________________________________________________________________________________
# dropout_406 (Dropout)           (None, 32, 32, 16)   0           conv2d_415[0][0]
# __________________________________________________________________________________________________
# concatenate_450 (Concatenate)   (None, 32, 32, 352)  0           max_pooling2d_23[0][0]
#                                                                  dropout_404[0][0]
#                                                                  dropout_405[0][0]
#                                                                  dropout_406[0][0]
# __________________________________________________________________________________________________
# batch_normalization_407 (BatchN (None, 32, 32, 352)  1408        concatenate_450[0][0]
# __________________________________________________________________________________________________
# activation_407 (Activation)     (None, 32, 32, 352)  0           batch_normalization_407[0][0]
# __________________________________________________________________________________________________
# conv2d_416 (Conv2D)             (None, 32, 32, 16)   50704       activation_407[0][0]
# __________________________________________________________________________________________________
# dropout_407 (Dropout)           (None, 32, 32, 16)   0           conv2d_416[0][0]
# __________________________________________________________________________________________________
# concatenate_451 (Concatenate)   (None, 32, 32, 368)  0           max_pooling2d_23[0][0]
#                                                                  dropout_404[0][0]
#                                                                  dropout_405[0][0]
#                                                                  dropout_406[0][0]
#                                                                  dropout_407[0][0]
# __________________________________________________________________________________________________
# batch_normalization_408 (BatchN (None, 32, 32, 368)  1472        concatenate_451[0][0]
# __________________________________________________________________________________________________
# activation_408 (Activation)     (None, 32, 32, 368)  0           batch_normalization_408[0][0]
# __________________________________________________________________________________________________
# conv2d_417 (Conv2D)             (None, 32, 32, 16)   53008       activation_408[0][0]
# __________________________________________________________________________________________________
# dropout_408 (Dropout)           (None, 32, 32, 16)   0           conv2d_417[0][0]
# __________________________________________________________________________________________________
# concatenate_452 (Concatenate)   (None, 32, 32, 384)  0           max_pooling2d_23[0][0]
#                                                                  dropout_404[0][0]
#                                                                  dropout_405[0][0]
#                                                                  dropout_406[0][0]
#                                                                  dropout_407[0][0]
#                                                                  dropout_408[0][0]
# __________________________________________________________________________________________________
# batch_normalization_409 (BatchN (None, 32, 32, 384)  1536        concatenate_452[0][0]
# __________________________________________________________________________________________________
# activation_409 (Activation)     (None, 32, 32, 384)  0           batch_normalization_409[0][0]
# __________________________________________________________________________________________________
# conv2d_418 (Conv2D)             (None, 32, 32, 16)   55312       activation_409[0][0]
# __________________________________________________________________________________________________
# dropout_409 (Dropout)           (None, 32, 32, 16)   0           conv2d_418[0][0]
# __________________________________________________________________________________________________
# concatenate_453 (Concatenate)   (None, 32, 32, 400)  0           max_pooling2d_23[0][0]
#                                                                  dropout_404[0][0]
#                                                                  dropout_405[0][0]
#                                                                  dropout_406[0][0]
#                                                                  dropout_407[0][0]
#                                                                  dropout_408[0][0]
#                                                                  dropout_409[0][0]
# __________________________________________________________________________________________________
# batch_normalization_410 (BatchN (None, 32, 32, 400)  1600        concatenate_453[0][0]
# __________________________________________________________________________________________________
# activation_410 (Activation)     (None, 32, 32, 400)  0           batch_normalization_410[0][0]
# __________________________________________________________________________________________________
# conv2d_419 (Conv2D)             (None, 32, 32, 16)   57616       activation_410[0][0]
# __________________________________________________________________________________________________
# dropout_410 (Dropout)           (None, 32, 32, 16)   0           conv2d_419[0][0]
# __________________________________________________________________________________________________
# concatenate_454 (Concatenate)   (None, 32, 32, 416)  0           max_pooling2d_23[0][0]
#                                                                  dropout_404[0][0]
#                                                                  dropout_405[0][0]
#                                                                  dropout_406[0][0]
#                                                                  dropout_407[0][0]
#                                                                  dropout_408[0][0]
#                                                                  dropout_409[0][0]
#                                                                  dropout_410[0][0]
# __________________________________________________________________________________________________
# batch_normalization_411 (BatchN (None, 32, 32, 416)  1664        concatenate_454[0][0]
# __________________________________________________________________________________________________
# activation_411 (Activation)     (None, 32, 32, 416)  0           batch_normalization_411[0][0]
# __________________________________________________________________________________________________
# conv2d_420 (Conv2D)             (None, 32, 32, 16)   59920       activation_411[0][0]
# __________________________________________________________________________________________________
# dropout_411 (Dropout)           (None, 32, 32, 16)   0           conv2d_420[0][0]
# __________________________________________________________________________________________________
# concatenate_455 (Concatenate)   (None, 32, 32, 432)  0           max_pooling2d_23[0][0]
#                                                                  dropout_404[0][0]
#                                                                  dropout_405[0][0]
#                                                                  dropout_406[0][0]
#                                                                  dropout_407[0][0]
#                                                                  dropout_408[0][0]
#                                                                  dropout_409[0][0]
#                                                                  dropout_410[0][0]
#                                                                  dropout_411[0][0]
# __________________________________________________________________________________________________
# batch_normalization_412 (BatchN (None, 32, 32, 432)  1728        concatenate_455[0][0]
# __________________________________________________________________________________________________
# activation_412 (Activation)     (None, 32, 32, 432)  0           batch_normalization_412[0][0]
# __________________________________________________________________________________________________
# conv2d_421 (Conv2D)             (None, 32, 32, 16)   62224       activation_412[0][0]
# __________________________________________________________________________________________________
# dropout_412 (Dropout)           (None, 32, 32, 16)   0           conv2d_421[0][0]
# __________________________________________________________________________________________________
# concatenate_456 (Concatenate)   (None, 32, 32, 448)  0           max_pooling2d_23[0][0]
#                                                                  dropout_404[0][0]
#                                                                  dropout_405[0][0]
#                                                                  dropout_406[0][0]
#                                                                  dropout_407[0][0]
#                                                                  dropout_408[0][0]
#                                                                  dropout_409[0][0]
#                                                                  dropout_410[0][0]
#                                                                  dropout_411[0][0]
#                                                                  dropout_412[0][0]
# __________________________________________________________________________________________________
# batch_normalization_413 (BatchN (None, 32, 32, 448)  1792        concatenate_456[0][0]
# __________________________________________________________________________________________________
# activation_413 (Activation)     (None, 32, 32, 448)  0           batch_normalization_413[0][0]
# __________________________________________________________________________________________________
# conv2d_422 (Conv2D)             (None, 32, 32, 16)   64528       activation_413[0][0]
# __________________________________________________________________________________________________
# dropout_413 (Dropout)           (None, 32, 32, 16)   0           conv2d_422[0][0]
# __________________________________________________________________________________________________
# concatenate_457 (Concatenate)   (None, 32, 32, 160)  0           dropout_404[0][0]
#                                                                  dropout_405[0][0]
#                                                                  dropout_406[0][0]
#                                                                  dropout_407[0][0]
#                                                                  dropout_408[0][0]
#                                                                  dropout_409[0][0]
#                                                                  dropout_410[0][0]
#                                                                  dropout_411[0][0]
#                                                                  dropout_412[0][0]
#                                                                  dropout_413[0][0]
# __________________________________________________________________________________________________
# concatenate_458 (Concatenate)   (None, 32, 32, 464)  0           max_pooling2d_23[0][0]
#                                                                  concatenate_457[0][0]
# __________________________________________________________________________________________________
# batch_normalization_414 (BatchN (None, 32, 32, 464)  1856        concatenate_458[0][0]
# __________________________________________________________________________________________________
# activation_414 (Activation)     (None, 32, 32, 464)  0           batch_normalization_414[0][0]
# __________________________________________________________________________________________________
# conv2d_423 (Conv2D)             (None, 32, 32, 464)  215760      activation_414[0][0]
# __________________________________________________________________________________________________
# dropout_414 (Dropout)           (None, 32, 32, 464)  0           conv2d_423[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_24 (MaxPooling2D) (None, 16, 16, 464)  0           dropout_414[0][0]
# __________________________________________________________________________________________________
# batch_normalization_415 (BatchN (None, 16, 16, 464)  1856        max_pooling2d_24[0][0]
# __________________________________________________________________________________________________
# activation_415 (Activation)     (None, 16, 16, 464)  0           batch_normalization_415[0][0]
# __________________________________________________________________________________________________
# conv2d_424 (Conv2D)             (None, 16, 16, 16)   66832       activation_415[0][0]
# __________________________________________________________________________________________________
# dropout_415 (Dropout)           (None, 16, 16, 16)   0           conv2d_424[0][0]
# __________________________________________________________________________________________________
# concatenate_459 (Concatenate)   (None, 16, 16, 480)  0           max_pooling2d_24[0][0]
#                                                                  dropout_415[0][0]
# __________________________________________________________________________________________________
# batch_normalization_416 (BatchN (None, 16, 16, 480)  1920        concatenate_459[0][0]
# __________________________________________________________________________________________________
# activation_416 (Activation)     (None, 16, 16, 480)  0           batch_normalization_416[0][0]
# __________________________________________________________________________________________________
# conv2d_425 (Conv2D)             (None, 16, 16, 16)   69136       activation_416[0][0]
# __________________________________________________________________________________________________
# dropout_416 (Dropout)           (None, 16, 16, 16)   0           conv2d_425[0][0]
# __________________________________________________________________________________________________
# concatenate_460 (Concatenate)   (None, 16, 16, 496)  0           max_pooling2d_24[0][0]
#                                                                  dropout_415[0][0]
#                                                                  dropout_416[0][0]
# __________________________________________________________________________________________________
# batch_normalization_417 (BatchN (None, 16, 16, 496)  1984        concatenate_460[0][0]
# __________________________________________________________________________________________________
# activation_417 (Activation)     (None, 16, 16, 496)  0           batch_normalization_417[0][0]
# __________________________________________________________________________________________________
# conv2d_426 (Conv2D)             (None, 16, 16, 16)   71440       activation_417[0][0]
# __________________________________________________________________________________________________
# dropout_417 (Dropout)           (None, 16, 16, 16)   0           conv2d_426[0][0]
# __________________________________________________________________________________________________
# concatenate_461 (Concatenate)   (None, 16, 16, 512)  0           max_pooling2d_24[0][0]
#                                                                  dropout_415[0][0]
#                                                                  dropout_416[0][0]
#                                                                  dropout_417[0][0]
# __________________________________________________________________________________________________
# batch_normalization_418 (BatchN (None, 16, 16, 512)  2048        concatenate_461[0][0]
# __________________________________________________________________________________________________
# activation_418 (Activation)     (None, 16, 16, 512)  0           batch_normalization_418[0][0]
# __________________________________________________________________________________________________
# conv2d_427 (Conv2D)             (None, 16, 16, 16)   73744       activation_418[0][0]
# __________________________________________________________________________________________________
# dropout_418 (Dropout)           (None, 16, 16, 16)   0           conv2d_427[0][0]
# __________________________________________________________________________________________________
# concatenate_462 (Concatenate)   (None, 16, 16, 528)  0           max_pooling2d_24[0][0]
#                                                                  dropout_415[0][0]
#                                                                  dropout_416[0][0]
#                                                                  dropout_417[0][0]
#                                                                  dropout_418[0][0]
# __________________________________________________________________________________________________
# batch_normalization_419 (BatchN (None, 16, 16, 528)  2112        concatenate_462[0][0]
# __________________________________________________________________________________________________
# activation_419 (Activation)     (None, 16, 16, 528)  0           batch_normalization_419[0][0]
# __________________________________________________________________________________________________
# conv2d_428 (Conv2D)             (None, 16, 16, 16)   76048       activation_419[0][0]
# __________________________________________________________________________________________________
# dropout_419 (Dropout)           (None, 16, 16, 16)   0           conv2d_428[0][0]
# __________________________________________________________________________________________________
# concatenate_463 (Concatenate)   (None, 16, 16, 544)  0           max_pooling2d_24[0][0]
#                                                                  dropout_415[0][0]
#                                                                  dropout_416[0][0]
# ...
# activation_477 (Activation)     (None, 256, 256, 192 0           batch_normalization_477[0][0]
# __________________________________________________________________________________________________
# conv2d_486 (Conv2D)             (None, 256, 256, 16) 27664       activation_477[0][0]
# __________________________________________________________________________________________________
# dropout_477 (Dropout)           (None, 256, 256, 16) 0           conv2d_486[0][0]
# __________________________________________________________________________________________________
# concatenate_531 (Concatenate)   (None, 256, 256, 208 0           concatenate_530[0][0]
#                                                                  dropout_477[0][0]
# __________________________________________________________________________________________________
# batch_normalization_478 (BatchN (None, 256, 256, 208 832         concatenate_531[0][0]
# __________________________________________________________________________________________________
# activation_478 (Activation)     (None, 256, 256, 208 0           batch_normalization_478[0][0]
# __________________________________________________________________________________________________
# conv2d_487 (Conv2D)             (None, 256, 256, 16) 29968       activation_478[0][0]
# __________________________________________________________________________________________________
# dropout_478 (Dropout)           (None, 256, 256, 16) 0           conv2d_487[0][0]
# __________________________________________________________________________________________________
# concatenate_532 (Concatenate)   (None, 256, 256, 224 0           concatenate_530[0][0]
#                                                                  dropout_477[0][0]
#                                                                  dropout_478[0][0]
# __________________________________________________________________________________________________
# batch_normalization_479 (BatchN (None, 256, 256, 224 896         concatenate_532[0][0]
# __________________________________________________________________________________________________
# activation_479 (Activation)     (None, 256, 256, 224 0           batch_normalization_479[0][0]
# __________________________________________________________________________________________________
# conv2d_488 (Conv2D)             (None, 256, 256, 16) 32272       activation_479[0][0]
# __________________________________________________________________________________________________
# dropout_479 (Dropout)           (None, 256, 256, 16) 0           conv2d_488[0][0]
# __________________________________________________________________________________________________
# concatenate_533 (Concatenate)   (None, 256, 256, 240 0           concatenate_530[0][0]
#                                                                  dropout_477[0][0]
#                                                                  dropout_478[0][0]
#                                                                  dropout_479[0][0]
# __________________________________________________________________________________________________
# batch_normalization_480 (BatchN (None, 256, 256, 240 960         concatenate_533[0][0]
# __________________________________________________________________________________________________
# activation_480 (Activation)     (None, 256, 256, 240 0           batch_normalization_480[0][0]
# __________________________________________________________________________________________________
# conv2d_489 (Conv2D)             (None, 256, 256, 16) 34576       activation_480[0][0]
# __________________________________________________________________________________________________
# dropout_480 (Dropout)           (None, 256, 256, 16) 0           conv2d_489[0][0]
# __________________________________________________________________________________________________
# concatenate_534 (Concatenate)   (None, 256, 256, 64) 0           dropout_477[0][0]
#                                                                  dropout_478[0][0]
#                                                                  dropout_479[0][0]
#                                                                  dropout_480[0][0]
# __________________________________________________________________________________________________
# concatenate_535 (Concatenate)   (None, 256, 256, 256 0           concatenate_530[0][0]
#                                                                  concatenate_534[0][0]
# __________________________________________________________________________________________________
# conv2d_490 (Conv2D)             (None, 256, 256, 11) 2827        concatenate_535[0][0]
# ==================================================================================================
# Total params: 14,021,643
# Trainable params: 13,918,571
# Non-trainable params: 103,072
# __________________________________________________________________________________________________
# Epoch 1/1
# 15/15 [==============================] - 69s 5s/step - loss: 5.7474 - jaccard_distance: 1.2360
# Loss : [5.747439289093018]  Jaccard Distance : [1.2360424359639486]
# Epoch 1/1
# 15/15 [==============================] - 2s 109ms/step - loss: 4.3884 - jaccard_distance: 0.6012
# Loss : [4.388356002171834]  Jaccard Distance : [0.6012034237384796]
# Epoch 1/1
# 15/15 [==============================] - 2s 109ms/step - loss: 1.7101 - jaccard_distance: 0.2309
# Loss : [1.7101431528727213]  Jaccard Distance : [0.2309314101934433]
# Epoch 1/1
# 10/10 [==============================] - 4s 408ms/step - loss: 1.0740 - jaccard_distance: 0.1561
# Loss : [1.0740339756011963]  Jaccard Distance : [0.1561465859413147]
# Epoch 1/1
# 15/15 [==============================] - 2s 108ms/step - loss: 3.3432 - jaccard_distance: 0.5027
# Loss : [3.343176571528117]  Jaccard Distance : [0.5026540756225586]
# Epoch 1/1
# 15/15 [==============================] - 2s 108ms/step - loss: 2.6348 - jaccard_distance: 0.4347
# Loss : [2.6348089853922527]  Jaccard Distance : [0.43468348383903505]
# Epoch 1/1
# 15/15 [==============================] - 2s 108ms/step - loss: 2.1822 - jaccard_distance: 0.3911
# Loss : [2.182164764404297]  Jaccard Distance : [0.39108633399009707]
# Epoch 1/1
# 10/10 [==============================] - 1s 111ms/step - loss: 1.4299 - jaccard_distance: 0.3451
# Loss : [1.429919958114624]  Jaccard Distance : [0.34510446190834043]
# Epoch 1/1
# 15/15 [==============================] - 2s 109ms/step - loss: 3.1283 - jaccard_distance: 0.5464
# Loss : [3.1282901843388875]  Jaccard Distance : [0.5464165906111399]
# Epoch 1/1
# 15/15 [==============================] - 2s 108ms/step - loss: 2.0334 - jaccard_distance: 0.4195
# Loss : [2.0333607673645018]  Jaccard Distance : [0.41949923237164816]
# Epoch 1/1
# 15/15 [==============================] - 2s 107ms/step - loss: 2.0480 - jaccard_distance: 0.4414
# Loss : [2.0479522228240965]  Jaccard Distance : [0.4413591086864471]
# Epoch 1/1
# 10/10 [==============================] - 1s 111ms/step - loss: 1.9878 - jaccard_distance: 0.4611
# Loss : [1.9877629041671754]  Jaccard Distance : [0.4610751748085022]
# Epoch 1/1
# 15/15 [==============================] - 2s 108ms/step - loss: 1.9511 - jaccard_distance: 0.3784
# Loss : [1.95107244849205]  Jaccard Distance : [0.378383152683576]
# Epoch 1/1
# 15/15 [==============================] - 2s 109ms/step - loss: 0.5845 - jaccard_distance: 0.2208
# Loss : [0.5844609181086222]  Jaccard Distance : [0.22084321479002636]
# Epoch 1/1
# 15/15 [==============================] - 2s 110ms/step - loss: 0.3393 - jaccard_distance: 0.1674
# Loss : [0.3392699460188548]  Jaccard Distance : [0.1674412876367569]
# Epoch 1/1
# 10/10 [==============================] - 1s 113ms/step - loss: 0.5341 - jaccard_distance: 0.2129
# Loss : [0.5341494798660278]  Jaccard Distance : [0.21290746331214905]
# Epoch 1/1
# 15/15 [==============================] - 2s 108ms/step - loss: 5.0496 - jaccard_distance: 1.0425
# Loss : [5.049603287378947]  Jaccard Distance : [1.0425366242726644]
# Epoch 1/1
# 15/15 [==============================] - 2s 108ms/step - loss: 2.7988 - jaccard_distance: 0.7202
# Loss : [2.7987556934356688]  Jaccard Distance : [0.7202372590700785]
# Epoch 1/1
# 15/15 [==============================] - 2s 108ms/step - loss: 2.0453 - jaccard_distance: 0.5898
# Loss : [2.045259626706441]  Jaccard Distance : [0.5898325800895691]
# Epoch 1/1
# 10/10 [==============================] - 1s 112ms/step - loss: 1.3257 - jaccard_distance: 0.4124
# Loss : [1.3256577968597412]  Jaccard Distance : [0.41235439777374266]
# Epoch 1/1
# 15/15 [==============================] - 2s 108ms/step - loss: 1.9631 - jaccard_distance: 0.4746
# Loss : [1.9631211201349894]  Jaccard Distance : [0.47457231680552164]
# Epoch 1/1
# 15/15 [==============================] - 2s 108ms/step - loss: 0.8268 - jaccard_distance: 0.3155
# Loss : [0.8267953753471374]  Jaccard Distance : [0.31551562746365863]
# Epoch 1/1
# 15/15 [==============================] - 2s 107ms/step - loss: 0.4200 - jaccard_distance: 0.2468
# Loss : [0.42001713116963707]  Jaccard Distance : [0.24680905242760975]
# Epoch 1/1
# 10/10 [==============================] - 1s 112ms/step - loss: 0.3354 - jaccard_distance: 0.2001
# Loss : [0.3354056715965271]  Jaccard Distance : [0.20005991756916047]
# Epoch 1/1
# 15/15 [==============================] - 2s 108ms/step - loss: 1.3514 - jaccard_distance: 0.4440
# Loss : [1.3514434734980265]  Jaccard Distance : [0.443956991036733]
# Epoch 1/1
# 15/15 [==============================] - 2s 108ms/step - loss: 0.6652 - jaccard_distance: 0.3075
# Loss : [0.6651737709840139]  Jaccard Distance : [0.3074593722820282]
# Epoch 1/1
# 15/15 [==============================] - 2s 109ms/step - loss: 0.4284 - jaccard_distance: 0.2613
# Loss : [0.4283545275529226]  Jaccard Distance : [0.2613430182139079]
# Epoch 1/1
# 10/10 [==============================] - 1s 113ms/step - loss: 0.3498 - jaccard_distance: 0.2392
# Loss : [0.3497604072093964]  Jaccard Distance : [0.2391874760389328]
# Epoch 1/1
# 15/15 [==============================] - 2s 108ms/step - loss: 0.7826 - jaccard_distance: 0.3687
# Loss : [0.7825982292493184]  Jaccard Distance : [0.3686554551124573]
# Epoch 1/1
# 15/15 [==============================] - 2s 108ms/step - loss: 0.3551 - jaccard_distance: 0.2697
# Loss : [0.3550594409306844]  Jaccard Distance : [0.26969435314337414]
# Epoch 1/1
# 15/15 [==============================] - 2s 107ms/step - loss: 0.4138 - jaccard_distance: 0.2850
# Loss : [0.41383898854255674]  Jaccard Distance : [0.2850287993748983]
# Epoch 1/1
# 10/10 [==============================] - 1s 112ms/step - loss: 0.3741 - jaccard_distance: 0.2686
# Loss : [0.3741225600242615]  Jaccard Distance : [0.26857446432113646]
# Epoch 1/1
# 15/15 [==============================] - 2s 107ms/step - loss: 4.9191 - jaccard_distance: 0.9228
# Loss : [4.9190536896387735]  Jaccard Distance : [0.9227625211079915]
# Epoch 1/1
# 15/15 [==============================] - 2s 107ms/step - loss: 1.3092 - jaccard_distance: 0.2890
# Loss : [1.3091768185297648]  Jaccard Distance : [0.2889822413523992]
# Epoch 1/1
# 15/15 [==============================] - 2s 108ms/step - loss: 0.5916 - jaccard_distance: 0.2547
# Loss : [0.5916470487912496]  Jaccard Distance : [0.2547093947728475]
# Epoch 1/1
# 10/10 [==============================] - 1s 111ms/step - loss: 0.6402 - jaccard_distance: 0.3098
# Loss : [0.6401807785034179]  Jaccard Distance : [0.30979539155960084]
# Epoch 1/1
# 15/15 [==============================] - 2s 107ms/step - loss: 5.9347 - jaccard_distance: 1.3166
# Loss : [5.934693543116252]  Jaccard Distance : [1.3166006644566854]
# Epoch 1/1
# 15/15 [==============================] - 2s 108ms/step - loss: 0.9471 - jaccard_distance: 0.5020
# Loss : [0.9471317966779073]  Jaccard Distance : [0.5019924720128377]
# Epoch 1/1
# 15/15 [==============================] - 2s 108ms/step - loss: 0.4766 - jaccard_distance: 0.3913
# Loss : [0.4766363203525543]  Jaccard Distance : [0.39130906462669374]
# Epoch 1/1
# 10/10 [==============================] - 1s 114ms/step - loss: 0.7591 - jaccard_distance: 0.4731
# Loss : [0.7591269612312317]  Jaccard Distance : [0.4730734467506409]
# Epoch 1/1
# 15/15 [==============================] - 2s 109ms/step - loss: 1.7585 - jaccard_distance: 0.7856
# Loss : [1.7584710439046225]  Jaccard Distance : [0.7855521082878113]
# Epoch 1/1
# 15/15 [==============================] - 2s 107ms/step - loss: 0.6985 - jaccard_distance: 0.4622
# Loss : [0.698484472433726]  Jaccard Distance : [0.4622003257274628]
# Epoch 1/1
# 15/15 [==============================] - 2s 107ms/step - loss: 0.6395 - jaccard_distance: 0.3953
# Loss : [0.6394657929738362]  Jaccard Distance : [0.39531333645184835]
# Epoch 1/1
# 10/10 [==============================] - 1s 111ms/step - loss: 0.3602 - jaccard_distance: 0.2819
# Loss : [0.36024032831192015]  Jaccard Distance : [0.2819049060344696]
# Epoch 1/1
# 15/15 [==============================] - 2s 107ms/step - loss: 0.9066 - jaccard_distance: 0.5020
# Loss : [0.906583301226298]  Jaccard Distance : [0.501999020576477]
# Epoch 1/1
# 15/15 [==============================] - 2s 107ms/step - loss: 0.3140 - jaccard_distance: 0.2210
# Loss : [0.3140285889307658]  Jaccard Distance : [0.2209984411795934]
# Epoch 1/1
# 15/15 [==============================] - 2s 109ms/step - loss: 0.3263 - jaccard_distance: 0.2447
# Loss : [0.3263182620207469]  Jaccard Distance : [0.24471970001856486]
# Epoch 1/1
# 10/10 [==============================] - 1s 112ms/step - loss: 0.3597 - jaccard_distance: 0.2762
# Loss : [0.35973586440086364]  Jaccard Distance : [0.2761946201324463]
# Epoch 1/1
# 15/15 [==============================] - 2s 108ms/step - loss: 1.0102 - jaccard_distance: 0.4295
# Loss : [1.0102399667104085]  Jaccard Distance : [0.4294788877169291]
# Epoch 1/1
# 15/15 [==============================] - 2s 108ms/step - loss: 0.4122 - jaccard_distance: 0.2479
# Loss : [0.4121993084748586]  Jaccard Distance : [0.24793745080629984]
# Epoch 1/1
# 15/15 [==============================] - 2s 108ms/step - loss: 0.5043 - jaccard_distance: 0.2626
# Loss : [0.5043332815170288]  Jaccard Distance : [0.26262857218583424]
# Epoch 1/1
# 10/10 [==============================] - 1s 114ms/step - loss: 0.3748 - jaccard_distance: 0.2600
# Loss : [0.37478214502334595]  Jaccard Distance : [0.26000537872314455]
# Epoch 1/1
# 15/15 [==============================] - 2s 108ms/step - loss: 0.8075 - jaccard_distance: 0.4639
# Loss : [0.807474676767985]  Jaccard Distance : [0.4639393667380015]
# Epoch 1/1
# 15/15 [==============================] - 2s 108ms/step - loss: 0.4683 - jaccard_distance: 0.3673
# Loss : [0.46828915079434713]  Jaccard Distance : [0.367344997326533]
# Epoch 1/1
# 15/15 [==============================] - 2s 108ms/step - loss: 0.4169 - jaccard_distance: 0.3451
# Loss : [0.4169279674688975]  Jaccard Distance : [0.34511880079905194]
# Epoch 1/1
# 10/10 [==============================] - 1s 112ms/step - loss: 0.4985 - jaccard_distance: 0.3673
# Loss : [0.49852149486541747]  Jaccard Distance : [0.3672676682472229]
# Epoch 1/1
# 15/15 [==============================] - 2s 108ms/step - loss: 0.3532 - jaccard_distance: 0.2296
# Loss : [0.3531502236922582]  Jaccard Distance : [0.2296046147743861]
# Epoch 1/1
# 15/15 [==============================] - 2s 108ms/step - loss: 0.2775 - jaccard_distance: 0.2043
# Loss : [0.2775285164515177]  Jaccard Distance : [0.20426679253578187]
# Epoch 1/1
# 15/15 [==============================] - 2s 107ms/step - loss: 0.3489 - jaccard_distance: 0.1977
# Loss : [0.34889072477817534]  Jaccard Distance : [0.19765014151732127]
# Epoch 1/1
# 10/10 [==============================] - 1s 112ms/step - loss: 0.1580 - jaccard_distance: 0.1324
# Loss : [0.15796152353286744]  Jaccard Distance : [0.13243577033281326]

# %%
model.load_weights("models/newDensenetEpoch1.h5")

# %%
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 256, 256, 3)  0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 256, 256, 48) 1344        input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 256, 256, 48) 192         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 256, 256, 48) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 256, 256, 16) 6928        activation_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 256, 256, 16) 0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 256, 256, 64) 0           conv2d_1[0][0]
#                                                                  dropout_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 256, 256, 64) 256         concatenate_1[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 256, 256, 64) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 256, 256, 16) 9232        activation_2[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 256, 256, 16) 0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 256, 256, 80) 0           conv2d_1[0][0]
#                                                                  dropout_1[0][0]
#                                                                  dropout_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 256, 256, 80) 320         concatenate_2[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 256, 256, 80) 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 256, 256, 16) 11536       activation_3[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 256, 256, 16) 0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 256, 256, 96) 0           conv2d_1[0][0]
#                                                                  dropout_1[0][0]
#                                                                  dropout_2[0][0]
#                                                                  dropout_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 256, 256, 96) 384         concatenate_3[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 256, 256, 96) 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 256, 256, 16) 13840       activation_4[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 256, 256, 16) 0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 256, 256, 64) 0           dropout_1[0][0]
#                                                                  dropout_2[0][0]
#                                                                  dropout_3[0][0]
#                                                                  dropout_4[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 256, 256, 112 0           conv2d_1[0][0]
#                                                                  concatenate_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 256, 256, 112 448         concatenate_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 256, 256, 112 0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 256, 256, 112 12656       activation_5[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 256, 256, 112 0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 128, 128, 112 0           dropout_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 128, 128, 112 448         max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 128, 128, 112 0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 128, 128, 16) 16144       activation_6[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 128, 128, 16) 0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 128, 128, 128 0           max_pooling2d_1[0][0]
#                                                                  dropout_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 128, 128, 128 512         concatenate_6[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 128, 128, 128 0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 128, 128, 16) 18448       activation_7[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 128, 128, 16) 0           conv2d_8[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 128, 128, 144 0           max_pooling2d_1[0][0]
#                                                                  dropout_6[0][0]
#                                                                  dropout_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 128, 128, 144 576         concatenate_7[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 128, 128, 144 0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 128, 128, 16) 20752       activation_8[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 128, 128, 16) 0           conv2d_9[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 128, 128, 160 0           max_pooling2d_1[0][0]
#                                                                  dropout_6[0][0]
#                                                                  dropout_7[0][0]
#                                                                  dropout_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 128, 128, 160 640         concatenate_8[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 128, 128, 160 0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 128, 128, 16) 23056       activation_9[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 128, 128, 16) 0           conv2d_10[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 128, 128, 176 0           max_pooling2d_1[0][0]
#                                                                  dropout_6[0][0]
#                                                                  dropout_7[0][0]
#                                                                  dropout_8[0][0]
#                                                                  dropout_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 128, 128, 176 704         concatenate_9[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 128, 128, 176 0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 128, 128, 16) 25360       activation_10[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 128, 128, 16) 0           conv2d_11[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 128, 128, 80) 0           dropout_6[0][0]
#                                                                  dropout_7[0][0]
#                                                                  dropout_8[0][0]
#                                                                  dropout_9[0][0]
#                                                                  dropout_10[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 128, 128, 192 0           max_pooling2d_1[0][0]
#                                                                  concatenate_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 128, 128, 192 768         concatenate_11[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 128, 128, 192 0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 128, 128, 192 37056       activation_11[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 128, 128, 192 0           conv2d_12[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 64, 64, 192)  0           dropout_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 64, 64, 192)  768         max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 64, 64, 192)  0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 64, 64, 16)   27664       activation_12[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 64, 64, 16)   0           conv2d_13[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 64, 64, 208)  0           max_pooling2d_2[0][0]
#                                                                  dropout_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 64, 64, 208)  832         concatenate_12[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 64, 64, 208)  0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 64, 64, 16)   29968       activation_13[0][0]
# __________________________________________________________________________________________________
# dropout_13 (Dropout)            (None, 64, 64, 16)   0           conv2d_14[0][0]
# __________________________________________________________________________________________________
# concatenate_13 (Concatenate)    (None, 64, 64, 224)  0           max_pooling2d_2[0][0]
#                                                                  dropout_12[0][0]
#                                                                  dropout_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 64, 64, 224)  896         concatenate_13[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 64, 64, 224)  0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 64, 64, 16)   32272       activation_14[0][0]
# __________________________________________________________________________________________________
# dropout_14 (Dropout)            (None, 64, 64, 16)   0           conv2d_15[0][0]
# __________________________________________________________________________________________________
# concatenate_14 (Concatenate)    (None, 64, 64, 240)  0           max_pooling2d_2[0][0]
#                                                                  dropout_12[0][0]
#                                                                  dropout_13[0][0]
#                                                                  dropout_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 64, 64, 240)  960         concatenate_14[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 64, 64, 240)  0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 64, 64, 16)   34576       activation_15[0][0]
# __________________________________________________________________________________________________
# dropout_15 (Dropout)            (None, 64, 64, 16)   0           conv2d_16[0][0]
# __________________________________________________________________________________________________
# concatenate_15 (Concatenate)    (None, 64, 64, 256)  0           max_pooling2d_2[0][0]
#                                                                  dropout_12[0][0]
#                                                                  dropout_13[0][0]
#                                                                  dropout_14[0][0]
#                                                                  dropout_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 64, 64, 256)  1024        concatenate_15[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 64, 64, 256)  0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 64, 64, 16)   36880       activation_16[0][0]
# __________________________________________________________________________________________________
# dropout_16 (Dropout)            (None, 64, 64, 16)   0           conv2d_17[0][0]
# __________________________________________________________________________________________________
# concatenate_16 (Concatenate)    (None, 64, 64, 272)  0           max_pooling2d_2[0][0]
#                                                                  dropout_12[0][0]
#                                                                  dropout_13[0][0]
#                                                                  dropout_14[0][0]
#                                                                  dropout_15[0][0]
#                                                                  dropout_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 64, 64, 272)  1088        concatenate_16[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 64, 64, 272)  0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 64, 64, 16)   39184       activation_17[0][0]
# __________________________________________________________________________________________________
# dropout_17 (Dropout)            (None, 64, 64, 16)   0           conv2d_18[0][0]
# __________________________________________________________________________________________________
# concatenate_17 (Concatenate)    (None, 64, 64, 288)  0           max_pooling2d_2[0][0]
#                                                                  dropout_12[0][0]
#                                                                  dropout_13[0][0]
#                                                                  dropout_14[0][0]
#                                                                  dropout_15[0][0]
#                                                                  dropout_16[0][0]
#                                                                  dropout_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 64, 64, 288)  1152        concatenate_17[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 64, 64, 288)  0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 64, 64, 16)   41488       activation_18[0][0]
# __________________________________________________________________________________________________
# dropout_18 (Dropout)            (None, 64, 64, 16)   0           conv2d_19[0][0]
# __________________________________________________________________________________________________
# concatenate_18 (Concatenate)    (None, 64, 64, 112)  0           dropout_12[0][0]
#                                                                  dropout_13[0][0]
#                                                                  dropout_14[0][0]
#                                                                  dropout_15[0][0]
#                                                                  dropout_16[0][0]
#                                                                  dropout_17[0][0]
#                                                                  dropout_18[0][0]
# __________________________________________________________________________________________________
# concatenate_19 (Concatenate)    (None, 64, 64, 304)  0           max_pooling2d_2[0][0]
#                                                                  concatenate_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 64, 64, 304)  1216        concatenate_19[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 64, 64, 304)  0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 64, 64, 304)  92720       activation_19[0][0]
# __________________________________________________________________________________________________
# dropout_19 (Dropout)            (None, 64, 64, 304)  0           conv2d_20[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 32, 32, 304)  0           dropout_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 32, 32, 304)  1216        max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 32, 32, 304)  0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 32, 32, 16)   43792       activation_20[0][0]
# __________________________________________________________________________________________________
# dropout_20 (Dropout)            (None, 32, 32, 16)   0           conv2d_21[0][0]
# __________________________________________________________________________________________________
# concatenate_20 (Concatenate)    (None, 32, 32, 320)  0           max_pooling2d_3[0][0]
#                                                                  dropout_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 32, 32, 320)  1280        concatenate_20[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 32, 32, 320)  0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 32, 32, 16)   46096       activation_21[0][0]
# __________________________________________________________________________________________________
# dropout_21 (Dropout)            (None, 32, 32, 16)   0           conv2d_22[0][0]
# __________________________________________________________________________________________________
# concatenate_21 (Concatenate)    (None, 32, 32, 336)  0           max_pooling2d_3[0][0]
#                                                                  dropout_20[0][0]
#                                                                  dropout_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 32, 32, 336)  1344        concatenate_21[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 32, 32, 336)  0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 32, 32, 16)   48400       activation_22[0][0]
# __________________________________________________________________________________________________
# dropout_22 (Dropout)            (None, 32, 32, 16)   0           conv2d_23[0][0]
# __________________________________________________________________________________________________
# concatenate_22 (Concatenate)    (None, 32, 32, 352)  0           max_pooling2d_3[0][0]
#                                                                  dropout_20[0][0]
#                                                                  dropout_21[0][0]
#                                                                  dropout_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 32, 32, 352)  1408        concatenate_22[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 32, 32, 352)  0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 32, 32, 16)   50704       activation_23[0][0]
# __________________________________________________________________________________________________
# dropout_23 (Dropout)            (None, 32, 32, 16)   0           conv2d_24[0][0]
# __________________________________________________________________________________________________
# concatenate_23 (Concatenate)    (None, 32, 32, 368)  0           max_pooling2d_3[0][0]
#                                                                  dropout_20[0][0]
#                                                                  dropout_21[0][0]
#                                                                  dropout_22[0][0]
#                                                                  dropout_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 32, 32, 368)  1472        concatenate_23[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 32, 32, 368)  0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 32, 32, 16)   53008       activation_24[0][0]
# __________________________________________________________________________________________________
# dropout_24 (Dropout)            (None, 32, 32, 16)   0           conv2d_25[0][0]
# __________________________________________________________________________________________________
# concatenate_24 (Concatenate)    (None, 32, 32, 384)  0           max_pooling2d_3[0][0]
#                                                                  dropout_20[0][0]
#                                                                  dropout_21[0][0]
#                                                                  dropout_22[0][0]
#                                                                  dropout_23[0][0]
#                                                                  dropout_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 32, 32, 384)  1536        concatenate_24[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 32, 32, 384)  0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 32, 32, 16)   55312       activation_25[0][0]
# __________________________________________________________________________________________________
# dropout_25 (Dropout)            (None, 32, 32, 16)   0           conv2d_26[0][0]
# __________________________________________________________________________________________________
# concatenate_25 (Concatenate)    (None, 32, 32, 400)  0           max_pooling2d_3[0][0]
#                                                                  dropout_20[0][0]
#                                                                  dropout_21[0][0]
#                                                                  dropout_22[0][0]
#                                                                  dropout_23[0][0]
#                                                                  dropout_24[0][0]
#                                                                  dropout_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 32, 32, 400)  1600        concatenate_25[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 32, 32, 400)  0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 32, 32, 16)   57616       activation_26[0][0]
# __________________________________________________________________________________________________
# dropout_26 (Dropout)            (None, 32, 32, 16)   0           conv2d_27[0][0]
# __________________________________________________________________________________________________
# concatenate_26 (Concatenate)    (None, 32, 32, 416)  0           max_pooling2d_3[0][0]
#                                                                  dropout_20[0][0]
#                                                                  dropout_21[0][0]
#                                                                  dropout_22[0][0]
#                                                                  dropout_23[0][0]
#                                                                  dropout_24[0][0]
#                                                                  dropout_25[0][0]
#                                                                  dropout_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 32, 32, 416)  1664        concatenate_26[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 32, 32, 416)  0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 32, 32, 16)   59920       activation_27[0][0]
# __________________________________________________________________________________________________
# dropout_27 (Dropout)            (None, 32, 32, 16)   0           conv2d_28[0][0]
# __________________________________________________________________________________________________
# concatenate_27 (Concatenate)    (None, 32, 32, 432)  0           max_pooling2d_3[0][0]
#                                                                  dropout_20[0][0]
#                                                                  dropout_21[0][0]
#                                                                  dropout_22[0][0]
#                                                                  dropout_23[0][0]
#                                                                  dropout_24[0][0]
#                                                                  dropout_25[0][0]
#                                                                  dropout_26[0][0]
#                                                                  dropout_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 32, 32, 432)  1728        concatenate_27[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 32, 32, 432)  0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 32, 32, 16)   62224       activation_28[0][0]
# __________________________________________________________________________________________________
# dropout_28 (Dropout)            (None, 32, 32, 16)   0           conv2d_29[0][0]
# __________________________________________________________________________________________________
# concatenate_28 (Concatenate)    (None, 32, 32, 448)  0           max_pooling2d_3[0][0]
#                                                                  dropout_20[0][0]
#                                                                  dropout_21[0][0]
#                                                                  dropout_22[0][0]
#                                                                  dropout_23[0][0]
#                                                                  dropout_24[0][0]
#                                                                  dropout_25[0][0]
#                                                                  dropout_26[0][0]
#                                                                  dropout_27[0][0]
#                                                                  dropout_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 32, 32, 448)  1792        concatenate_28[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 32, 32, 448)  0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 32, 32, 16)   64528       activation_29[0][0]
# __________________________________________________________________________________________________
# dropout_29 (Dropout)            (None, 32, 32, 16)   0           conv2d_30[0][0]
# __________________________________________________________________________________________________
# concatenate_29 (Concatenate)    (None, 32, 32, 160)  0           dropout_20[0][0]
#                                                                  dropout_21[0][0]
#                                                                  dropout_22[0][0]
#                                                                  dropout_23[0][0]
#                                                                  dropout_24[0][0]
#                                                                  dropout_25[0][0]
#                                                                  dropout_26[0][0]
#                                                                  dropout_27[0][0]
#                                                                  dropout_28[0][0]
#                                                                  dropout_29[0][0]
# __________________________________________________________________________________________________
# concatenate_30 (Concatenate)    (None, 32, 32, 464)  0           max_pooling2d_3[0][0]
#                                                                  concatenate_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 32, 32, 464)  1856        concatenate_30[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 32, 32, 464)  0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 32, 32, 464)  215760      activation_30[0][0]
# __________________________________________________________________________________________________
# dropout_30 (Dropout)            (None, 32, 32, 464)  0           conv2d_31[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 16, 16, 464)  0           dropout_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 16, 16, 464)  1856        max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 16, 16, 464)  0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 16, 16, 16)   66832       activation_31[0][0]
# __________________________________________________________________________________________________
# dropout_31 (Dropout)            (None, 16, 16, 16)   0           conv2d_32[0][0]
# __________________________________________________________________________________________________
# concatenate_31 (Concatenate)    (None, 16, 16, 480)  0           max_pooling2d_4[0][0]
#                                                                  dropout_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 16, 16, 480)  1920        concatenate_31[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 16, 16, 480)  0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 16, 16, 16)   69136       activation_32[0][0]
# __________________________________________________________________________________________________
# dropout_32 (Dropout)            (None, 16, 16, 16)   0           conv2d_33[0][0]
# __________________________________________________________________________________________________
# concatenate_32 (Concatenate)    (None, 16, 16, 496)  0           max_pooling2d_4[0][0]
#                                                                  dropout_31[0][0]
#                                                                  dropout_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 16, 16, 496)  1984        concatenate_32[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 16, 16, 496)  0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 16, 16, 16)   71440       activation_33[0][0]
# __________________________________________________________________________________________________
# dropout_33 (Dropout)            (None, 16, 16, 16)   0           conv2d_34[0][0]
# __________________________________________________________________________________________________
# concatenate_33 (Concatenate)    (None, 16, 16, 512)  0           max_pooling2d_4[0][0]
#                                                                  dropout_31[0][0]
#                                                                  dropout_32[0][0]
#                                                                  dropout_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 16, 16, 512)  2048        concatenate_33[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 16, 16, 512)  0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 16, 16, 16)   73744       activation_34[0][0]
# __________________________________________________________________________________________________
# dropout_34 (Dropout)            (None, 16, 16, 16)   0           conv2d_35[0][0]
# __________________________________________________________________________________________________
# concatenate_34 (Concatenate)    (None, 16, 16, 528)  0           max_pooling2d_4[0][0]
#                                                                  dropout_31[0][0]
#                                                                  dropout_32[0][0]
#                                                                  dropout_33[0][0]
#                                                                  dropout_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 16, 16, 528)  2112        concatenate_34[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 16, 16, 528)  0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 16, 16, 16)   76048       activation_35[0][0]
# __________________________________________________________________________________________________
# dropout_35 (Dropout)            (None, 16, 16, 16)   0           conv2d_36[0][0]
# __________________________________________________________________________________________________
# concatenate_35 (Concatenate)    (None, 16, 16, 544)  0           max_pooling2d_4[0][0]
#                                                                  dropout_31[0][0]
#                                                                  dropout_32[0][0]
# ...
#                                                                  dropout_82[0][0]
#                                                                  dropout_83[0][0]
#                                                                  dropout_84[0][0]
#                                                                  dropout_85[0][0]
#                                                                  dropout_86[0][0]
#                                                                  dropout_87[0][0]
# __________________________________________________________________________________________________
# concatenate_94 (Concatenate)    (None, 64, 64, 576)  0           concatenate_86[0][0]
#                                                                  concatenate_93[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 128, 128, 112 580720      concatenate_94[0][0]
# __________________________________________________________________________________________________
# concatenate_95 (Concatenate)    (None, 128, 128, 304 0           conv2d_transpose_4[0][0]
#                                                                  concatenate_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_88 (BatchNo (None, 128, 128, 304 1216        concatenate_95[0][0]
# __________________________________________________________________________________________________
# activation_88 (Activation)      (None, 128, 128, 304 0           batch_normalization_88[0][0]
# __________________________________________________________________________________________________
# conv2d_89 (Conv2D)              (None, 128, 128, 16) 43792       activation_88[0][0]
# __________________________________________________________________________________________________
# dropout_88 (Dropout)            (None, 128, 128, 16) 0           conv2d_89[0][0]
# __________________________________________________________________________________________________
# concatenate_96 (Concatenate)    (None, 128, 128, 320 0           concatenate_95[0][0]
#                                                                  dropout_88[0][0]
# __________________________________________________________________________________________________
# batch_normalization_89 (BatchNo (None, 128, 128, 320 1280        concatenate_96[0][0]
# __________________________________________________________________________________________________
# activation_89 (Activation)      (None, 128, 128, 320 0           batch_normalization_89[0][0]
# __________________________________________________________________________________________________
# conv2d_90 (Conv2D)              (None, 128, 128, 16) 46096       activation_89[0][0]
# __________________________________________________________________________________________________
# dropout_89 (Dropout)            (None, 128, 128, 16) 0           conv2d_90[0][0]
# __________________________________________________________________________________________________
# concatenate_97 (Concatenate)    (None, 128, 128, 336 0           concatenate_95[0][0]
#                                                                  dropout_88[0][0]
#                                                                  dropout_89[0][0]
# __________________________________________________________________________________________________
# batch_normalization_90 (BatchNo (None, 128, 128, 336 1344        concatenate_97[0][0]
# __________________________________________________________________________________________________
# activation_90 (Activation)      (None, 128, 128, 336 0           batch_normalization_90[0][0]
# __________________________________________________________________________________________________
# conv2d_91 (Conv2D)              (None, 128, 128, 16) 48400       activation_90[0][0]
# __________________________________________________________________________________________________
# dropout_90 (Dropout)            (None, 128, 128, 16) 0           conv2d_91[0][0]
# __________________________________________________________________________________________________
# concatenate_98 (Concatenate)    (None, 128, 128, 352 0           concatenate_95[0][0]
#                                                                  dropout_88[0][0]
#                                                                  dropout_89[0][0]
#                                                                  dropout_90[0][0]
# __________________________________________________________________________________________________
# batch_normalization_91 (BatchNo (None, 128, 128, 352 1408        concatenate_98[0][0]
# __________________________________________________________________________________________________
# activation_91 (Activation)      (None, 128, 128, 352 0           batch_normalization_91[0][0]
# __________________________________________________________________________________________________
# conv2d_92 (Conv2D)              (None, 128, 128, 16) 50704       activation_91[0][0]
# __________________________________________________________________________________________________
# dropout_91 (Dropout)            (None, 128, 128, 16) 0           conv2d_92[0][0]
# __________________________________________________________________________________________________
# concatenate_99 (Concatenate)    (None, 128, 128, 368 0           concatenate_95[0][0]
#                                                                  dropout_88[0][0]
#                                                                  dropout_89[0][0]
#                                                                  dropout_90[0][0]
#                                                                  dropout_91[0][0]
# __________________________________________________________________________________________________
# batch_normalization_92 (BatchNo (None, 128, 128, 368 1472        concatenate_99[0][0]
# __________________________________________________________________________________________________
# activation_92 (Activation)      (None, 128, 128, 368 0           batch_normalization_92[0][0]
# __________________________________________________________________________________________________
# conv2d_93 (Conv2D)              (None, 128, 128, 16) 53008       activation_92[0][0]
# __________________________________________________________________________________________________
# dropout_92 (Dropout)            (None, 128, 128, 16) 0           conv2d_93[0][0]
# __________________________________________________________________________________________________
# concatenate_100 (Concatenate)   (None, 128, 128, 80) 0           dropout_88[0][0]
#                                                                  dropout_89[0][0]
#                                                                  dropout_90[0][0]
#                                                                  dropout_91[0][0]
#                                                                  dropout_92[0][0]
# __________________________________________________________________________________________________
# concatenate_101 (Concatenate)   (None, 128, 128, 384 0           concatenate_95[0][0]
#                                                                  concatenate_100[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_5 (Conv2DTrans (None, 256, 256, 80) 276560      concatenate_101[0][0]
# __________________________________________________________________________________________________
# concatenate_102 (Concatenate)   (None, 256, 256, 192 0           conv2d_transpose_5[0][0]
#                                                                  concatenate_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_93 (BatchNo (None, 256, 256, 192 768         concatenate_102[0][0]
# __________________________________________________________________________________________________
# activation_93 (Activation)      (None, 256, 256, 192 0           batch_normalization_93[0][0]
# __________________________________________________________________________________________________
# conv2d_94 (Conv2D)              (None, 256, 256, 16) 27664       activation_93[0][0]
# __________________________________________________________________________________________________
# dropout_93 (Dropout)            (None, 256, 256, 16) 0           conv2d_94[0][0]
# __________________________________________________________________________________________________
# concatenate_103 (Concatenate)   (None, 256, 256, 208 0           concatenate_102[0][0]
#                                                                  dropout_93[0][0]
# __________________________________________________________________________________________________
# batch_normalization_94 (BatchNo (None, 256, 256, 208 832         concatenate_103[0][0]
# __________________________________________________________________________________________________
# activation_94 (Activation)      (None, 256, 256, 208 0           batch_normalization_94[0][0]
# __________________________________________________________________________________________________
# conv2d_95 (Conv2D)              (None, 256, 256, 16) 29968       activation_94[0][0]
# __________________________________________________________________________________________________
# dropout_94 (Dropout)            (None, 256, 256, 16) 0           conv2d_95[0][0]
# __________________________________________________________________________________________________
# concatenate_104 (Concatenate)   (None, 256, 256, 224 0           concatenate_102[0][0]
#                                                                  dropout_93[0][0]
#                                                                  dropout_94[0][0]
# __________________________________________________________________________________________________
# batch_normalization_95 (BatchNo (None, 256, 256, 224 896         concatenate_104[0][0]
# __________________________________________________________________________________________________
# activation_95 (Activation)      (None, 256, 256, 224 0           batch_normalization_95[0][0]
# __________________________________________________________________________________________________
# conv2d_96 (Conv2D)              (None, 256, 256, 16) 32272       activation_95[0][0]
# __________________________________________________________________________________________________
# dropout_95 (Dropout)            (None, 256, 256, 16) 0           conv2d_96[0][0]
# __________________________________________________________________________________________________
# concatenate_105 (Concatenate)   (None, 256, 256, 240 0           concatenate_102[0][0]
#                                                                  dropout_93[0][0]
#                                                                  dropout_94[0][0]
#                                                                  dropout_95[0][0]
# __________________________________________________________________________________________________
# batch_normalization_96 (BatchNo (None, 256, 256, 240 960         concatenate_105[0][0]
# __________________________________________________________________________________________________
# activation_96 (Activation)      (None, 256, 256, 240 0           batch_normalization_96[0][0]
# __________________________________________________________________________________________________
# conv2d_97 (Conv2D)              (None, 256, 256, 16) 34576       activation_96[0][0]
# __________________________________________________________________________________________________
# dropout_96 (Dropout)            (None, 256, 256, 16) 0           conv2d_97[0][0]
# __________________________________________________________________________________________________
# concatenate_106 (Concatenate)   (None, 256, 256, 64) 0           dropout_93[0][0]
#                                                                  dropout_94[0][0]
#                                                                  dropout_95[0][0]
#                                                                  dropout_96[0][0]
# __________________________________________________________________________________________________
# concatenate_107 (Concatenate)   (None, 256, 256, 256 0           concatenate_102[0][0]
#                                                                  concatenate_106[0][0]
# __________________________________________________________________________________________________
# conv2d_98 (Conv2D)              (None, 256, 256, 5)  1285        concatenate_107[0][0]
# ==================================================================================================
# Total params: 14,020,101
# Trainable params: 13,917,029
# Non-trainable params: 103,072
# __________________________________________________________________________________________________
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-8-ebbb0ec2f7bf> in <module>()
#       1 model = densenet(nb_classes=nb_classes,img_dim=(256,256,3),growth_rate=16)
# ----> 2 model.load_weights("models/newDensenetEpoch{}.h5".format(90))
#
# ~/anaconda3/lib/python3.6/site-packages/keras/engine/network.py in load_weights(self, filepath, by_name, skip_mismatch, reshape)
#    1155         if h5py is None:
#    1156             raise ImportError('`load_weights` requires h5py.')
# -> 1157         with h5py.File(filepath, mode='r') as f:
#    1158             if 'layer_names' not in f.attrs and 'model_weights' in f:
#    1159                 f = f['model_weights']
#
# ~/anaconda3/lib/python3.6/site-packages/h5py/_hl/files.py in __init__(self, name, mode, driver, libver, userblock_size, swmr, **kwds)
#     267             with phil:
#     268                 fapl = make_fapl(driver, libver, **kwds)
# --> 269                 fid = make_fid(name, mode, userblock_size, fapl, swmr=swmr)
#     270
#     271                 if swmr_support:
#
# ~/anaconda3/lib/python3.6/site-packages/h5py/_hl/files.py in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#      97         if swmr and swmr_support:
#      98             flags |= h5f.ACC_SWMR_READ
# ---> 99         fid = h5f.open(name, flags, fapl=fapl)
#     100     elif mode == 'r+':
#     101         fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/h5f.pyx in h5py.h5f.open()
#
# OSError: Unable to open file (unable to open file: name = 'models/newDensenetEpoch90.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)

# %%
x , y = next(proc.frame2label_train_datagen(size=(256,256) , batch_size = 80 , normalise = True))

# %%
image = x[0]
label = y[0]


label_classm = np.argmax(label , axis = -1)
print(label_classm.shape)
label_label = proc.class2image(label_classm)
plt.imshow(label_label)
plt.show()

plt.imshow(image)
plt.show()

pred = np.argmax(model.predict(np.array([image]))[0] , axis = -1)
# Out:
# (256, 256)

# %%
pred
# Out:
# array([[4, 4, 4, ..., 6, 6, 6],
#        [4, 4, 4, ..., 6, 6, 6],
#        [4, 4, 4, ..., 6, 6, 6],
#        ...,
#        [3, 2, 3, ..., 2, 2, 2],
#        [2, 2, 3, ..., 2, 2, 3],
#        [3, 3, 2, ..., 3, 2, 2]])

# %%
plt.imshow(proc.class2image(pred))
plt.show()
